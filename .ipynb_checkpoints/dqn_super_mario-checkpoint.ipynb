# %% [markdown]
# # 自律移動マリオやってみた

# %%
import sys
import os
import random

import gym
import ppaquette_gym_super_mario
import numpy as np
import cv2
import matplotlib.pyplot as plt

import torch
from torch import nn, optim

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# ## Wrapperの作成

# %%
class MaxAndSkipEnv(gym.Wrapper):
    
    def __init__(self, env, skip=4):
        gym.Wrapper.__init__(self, env)
        self._obs_buffer = np.zeros((2,)+env.observation_space.shape, dtype=np.uint8)
        self._skip       = skip

    def step(self, action):
        
        total_reward = 0.0
        done = None
        for i in range(self._skip):
            obs, reward, done, info = self.env.step(action)
            if i == self._skip - 2: self._obs_buffer[0] = obs
            if i == self._skip - 1: self._obs_buffer[1] = obs
            total_reward += reward
            if done:
                break
        max_frame = self._obs_buffer.max(axis=0)

        return max_frame, total_reward, done, info

    def reset(self, **kwargs):
        
        return self.env.reset(**kwargs)


class WarpFrame(gym.ObservationWrapper):
    
    def __init__(self, env, width=84, height=84, grayscale=True, dict_space_key=None):
        
        super().__init__(env)
        self._width = width
        self._height = height
        self._grayscale = grayscale
        self._key = dict_space_key
        if self._grayscale:
            num_colors = 1
        else:
            num_colors = 3

        new_space = gym.spaces.Box(
            low=0,
            high=255,
            shape=(self._height, self._width, num_colors),
            dtype=np.uint8,
        )
        if self._key is None:
            original_space = self.observation_space
            self.observation_space = new_space
        else:
            original_space = self.observation_space.spaces[self._key]
            self.observation_space.spaces[self._key] = new_space
        assert original_space.dtype == np.uint8 and len(original_space.shape) == 3

    def observation(self, obs):
        
        if self._key is None:
            frame = obs
        else:
            frame = obs[self._key]

        if self._grayscale:
            frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
        frame = cv2.resize(
            frame, (self._width, self._height), interpolation=cv2.INTER_AREA
        )
        if self._grayscale:
            frame = np.expand_dims(frame, -1)

        if self._key is None:
            obs = frame
        else:
            obs = obs.copy()
            obs[self._key] = frame
        return obs


class ClipRewardEnv(gym.RewardWrapper):
    
    def __init__(self, env):
        
        gym.RewardWrapper.__init__(self, env)

    def reward(self, reward):
        
        return np.sign(reward)


class LazyFrames(object):
    
    def __init__(self, frames):
        
        self._frames = frames
        self._out = None

    def _force(self):
        
        if self._out is None:
            self._out = np.concatenate(self._frames, axis=-1)
            self._frames = None
        return self._out

    def __array__(self, dtype=None):
        
        out = self._force()
        if dtype is not None:
            out = out.astype(dtype)
        return out

    def __len__(self):
        
        return len(self._force())

    def __getitem__(self, i):
        
        return self._force()[i]

    def count(self):
        
        frames = self._force()
        return frames.shape[frames.ndim - 1]

    def frame(self, i):
        
        return self._force()[..., i]
    
    
class TorchFrame(gym.ObservationWrapper):
    
    def __init__(self, env):
        
        super().__init__(env)
        height, width, channels = self.observation_space.shape
        self.observation_space = gym.spaces.Box(
            low=0,
            high=255,
            shape=(channels, height, width),
            dtype=np.uint8,
        )

    def observation(self, obs):
        
        return torch.as_tensor(obs.transpose([2, 0, 1]))

# %% [markdown]
# ##  環境生成

# %%
def make_action(command):
    
    if command == 0:
        return [0, 0, 0, 1, 0, 0]
    elif command == 1:
        return [0, 0, 0, 1, 1, 0]

# %%
def make_env(noop_max=30, skip=4, width=84, height=84, grayscale=True):
    
    env = gym.make('ppaquette/SuperMarioBros-1-1-v0')
    env = MaxAndSkipEnv(env, skip=skip)
    env = WarpFrame(env, width=width, height=height, grayscale=grayscale)
    env = ClipRewardEnv(env)
    env = TorchFrame(env)
    return env

env = make_env()
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.

# %%
def random_agent():
    
    for episode_ in range(5):
        obs_ = env.reset()
        total_reward_ = 0

        step_ = 0
        while True:
            action_ = make_action(np.random.randint(0, 2))
            obs_, reward_, done_, info_ = env.step(action_)
            total_reward_ += reward_
            if done_ or info_["time"] <= 200:
                break

            step_ += 1

        print(f"Episode: {episode_}, Step: {step_}, Reward: {total_reward_}")

#random_agent()
# Out:
# Episode: 0, Step: 78, Reward: 53.0
# Episode: 1, Step: 83, Reward: 52.0
# Episode: 2, Step: 122, Reward: 105.0
# Episode: 3, Step: 52, Reward: 52.0
# Episode: 4, Step: 92, Reward: 68.0

# %% [markdown]
# ## リプレイバッファ

# %%
class PrioritizedReplayBuffer(object):
    
    def __init__(self, buffer_size):
        
        self.buffer_size = buffer_size
        self.index = 0
        self.buffer = []
        self.priorities = np.zeros(buffer_size, dtype=np.float32)
        self.priorities[0] = 1.0
    
    def __len__(self):
        
        return len(self.buffer)

    # 経験をリプレイバッファに保存する． 経験は(obs, action, reward, next_obs, done)の5つ組を想定    
    def push(self, experience):
        
        if len(self.buffer) < self.buffer_size:
            self.buffer.append(experience)
        else:
            self.buffer[self.index] = experience

        # 優先度は最初は大きな値で初期化しておき, 後でサンプルされた時に更新する
        self.priorities[self.index] = self.priorities.max()
        self.index = (self.index + 1) % self.buffer_size
    
    def sample(self, batch_size, alpha=0.6, beta=0.4):
        
        # 現在経験が入っている部分に対応する優先度を取り出し, サンプルする確率を計算
        priorities = self.priorities[: self.buffer_size if len(self.buffer) == self.buffer_size else self.index]
        priorities = priorities ** alpha
        prob = priorities / priorities.sum()

        # 上で計算した確率に従ってリプレイバッファ中のインデックスをサンプルする
        indices = np.random.choice(len(self.buffer), batch_size, p=prob)

        # 学習の方向性を補正するための重みを計算
        weights = (len(self.buffer) * prob[indices]) ** (-beta)
        weights = weights / weights.max()

        # 上でサンプルしたインデックスに基づいて経験をサンプルし, (obs, action, reward, next_obs, done)に分ける
        obs, action, reward, next_obs, done = zip(*[self.buffer[i] for i in indices])

        # あとで計算しやすいようにtorch.Tensorに変換して(obs, action, reward, next_obs, done, indices, weights)の7つ組を返す
        return (torch.stack(obs),
                torch.as_tensor(action), 
                torch.as_tensor(reward, dtype=torch.float32),
                torch.stack(next_obs), 
                torch.as_tensor(done, dtype=torch.uint8),
                indices,
                torch.as_tensor(weights, dtype=torch.float32))

    # 優先度を更新する. 優先度が極端に小さくなって経験が全く選ばれないということがないように, 微小値を加算しておく.
    def update_priorities(self, indices, priorities):
        
        self.priorities[indices] = priorities + 1e-4

# %% [markdown]
# ## ネットワーク定義

# %%
class CNNQNetwork(nn.Module):
    
    def __init__(self, state_shape, n_action):
        
        super(CNNQNetwork, self).__init__()
        self.state_shape = state_shape
        self.n_action = n_action
        # Dueling Networkでも, 畳込み部分は共有する
        self.conv_layers = nn.Sequential(
            nn.Conv2d(state_shape[0], 32, kernel_size=8, stride=4),  # 1x84x84 -> 32x20x20
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),  # 32x20x20 -> 64x9x9
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),  # 64x9x9 -> 64x7x7
            nn.ReLU()
        )

        # Dueling Networkのための分岐した全結合層
        # 状態価値
        self.fc_state = nn.Sequential(
            nn.Linear(3136, 512),
            nn.ReLU(),
            nn.Linear(512, 1)
        )

        # アドバンテージ
        self.fc_advantage = nn.Sequential(
            nn.Linear(3136, 512),
            nn.ReLU(),
            nn.Linear(512, n_action)
        )
    
    def forward(self, obs):
        
        feature = self.conv_layers(obs)
        feature = feature.view(feature.size(0), -1)  #　Flatten. 64x7x7　-> 3136

        state_values = self.fc_state(feature)
        advantage = self.fc_advantage(feature)

        # 状態価値 + アドバンテージ で行動価値を計算しますが、安定化のためアドバンテージの（行動間での）平均を引きます
        action_values = state_values + advantage - torch.mean(advantage, dim=1, keepdim=True)
        return action_values

    # epsilon-greedy. 確率epsilonでランダムに行動し, それ以外はニューラルネットワークの予測結果に基づいてgreedyに行動します. 
    def act(self, obs, epsilon):
        
        if random.random() < epsilon:
            action = random.randrange(self.n_action)
        else:
            # 行動を選択する時には勾配を追跡する必要がない
            with torch.no_grad():
                action = torch.argmax(self.forward(obs.unsqueeze(0))).item()
        return action

# %% [markdown]
# ## 各種設定

# %%
buffer_size = 100000  #　リプレイバッファに入る経験の最大数
initial_buffer_size = 1000  # 学習を開始する最低限の経験の数
replay_buffer = PrioritizedReplayBuffer(buffer_size)

net = CNNQNetwork(env.observation_space.shape, n_action=2).to(device)
target_net = CNNQNetwork(env.observation_space.shape, n_action=2).to(device)
target_update_interval = 200  # 学習安定化のために用いるターゲットネットワークの同期間隔

optimizer = optim.Adam(net.parameters(), lr=1e-4)  # オプティマイザはAdam
loss_func = nn.SmoothL1Loss(reduction='none')  # ロスはSmoothL1loss（別名Huber loss）

beta_begin = 0.4
beta_end = 1.0
beta_decay = 500000
# beta_beginから始めてbeta_endまでbeta_decayかけて線形に増やす
beta_func = lambda step: min(beta_end, beta_begin + (beta_end - beta_begin) * (step / beta_decay))

epsilon_begin = 1.0
epsilon_end = 0.01
epsilon_decay = 50000
# epsilon_beginから始めてepsilon_endまでepsilon_decayかけて線形に減らす
epsilon_func = lambda step: max(epsilon_end, epsilon_begin - (epsilon_begin - epsilon_end) * (step / epsilon_decay))

gamma = 0.99  #　割引率
batch_size = 32
n_episodes = 1500  # 学習を行うエピソード数
time_limit = 200  # エピソードを打ち切るしきい値
model_path = "models"  # モデルの保存先

# %% [markdown]
# ## ネットワークの更新

# %%
def update(batch_size, beta):
    
    obs, action, reward, next_obs, done, indices, weights = replay_buffer.sample(batch_size, beta)
    obs, action, reward, next_obs, done, weights \
        = obs.float().to(device), action.to(device), reward.to(device), next_obs.float().to(device), done.to(device), weights.to(device)

    #　ニューラルネットワークによるQ関数の出力から, .gatherで実際に選択した行動に対応する価値を集めてきます.
    q_values = net(obs).gather(1, action.unsqueeze(1)).squeeze(1)
    
    # 目標値の計算なので勾配を追跡しない
    with torch.no_grad():
        # Double DQN. 
        # ① 現在のQ関数でgreedyに行動を選択し, 
        greedy_action_next = torch.argmax(net(next_obs), dim=1)
        # ②　対応する価値はターゲットネットワークのものを参照します.
        q_values_next = target_net(next_obs).gather(1, greedy_action_next.unsqueeze(1)).squeeze(1)

    # ベルマン方程式に基づき, 更新先の価値を計算します.
    # (1 - done)をかけているのは, ゲームが終わった後の価値は0とみなすためです.
    target_q_values = reward + gamma * q_values_next * (1 - done)

    # Prioritized Experience Replayのために, ロスに重み付けを行なって更新します.
    optimizer.zero_grad()
    loss = (weights * loss_func(q_values, target_q_values)).mean()
    loss.backward()
    optimizer.step()

    #　TD誤差に基づいて, サンプルされた経験の優先度を更新します.
    replay_buffer.update_priorities(indices, (target_q_values - q_values).abs().detach().cpu().numpy())

    return loss.item()

# %% [markdown]
# ## 学習スクリプト

# %%
os.makedirs(model_path, exist_ok=True)

step = 0
generation = 0
total_rewards = []
for episode in range(n_episodes):
    obs = env.reset()
    total_reward = 0

    while True:
        # ε-greedyで行動を選択
        action = net.act(obs.float().to(device), epsilon_func(step))
        # 環境中で実際に行動
        next_obs, reward, done, info = env.step(make_action(action))
        total_reward += reward

        # リプレイバッファに経験を蓄積
        replay_buffer.push([obs, action, reward, next_obs, done])
        obs = next_obs

        # ネットワークを更新            
        if len(replay_buffer) > initial_buffer_size:
            update(batch_size, beta_func(step))

        # ターゲットネットワークを定期的に同期させる
        if (step + 1) % target_update_interval == 0:
            target_net.load_state_dict(net.state_dict())
        
        step += 1
        
        if done or info["time"] <= time_limit:
            break

    total_rewards.append(total_reward)
    print(f"Episode: {episode+1}, Step: {step}, Reward: {total_reward}")
    
    if episode % 10 == 0:
        torch.save(net.state_dict(), os.path.join(model_path, f"dqn_agent_gen_{generation}.pt"))
        generation += 1

plt.plot(total_rewards, label="reward")
plt.legend()
plt.tight_layout()
# Out:
# Episode: 501, Step: 38211, Reward: 104.0
# Episode: 502, Step: 38290, Reward: 64.0
# Episode: 503, Step: 38430, Reward: 114.0
# Episode: 504, Step: 38548, Reward: 91.0
# Episode: 505, Step: 38631, Reward: 83.0
# Episode: 506, Step: 38692, Reward: 56.0
# Episode: 507, Step: 38742, Reward: 50.0
# Episode: 508, Step: 38852, Reward: 106.0
# Episode: 509, Step: 38956, Reward: 95.0
# Episode: 510, Step: 39007, Reward: 51.0
# Episode: 511, Step: 39088, Reward: 81.0
# Episode: 512, Step: 39174, Reward: 86.0
# Episode: 513, Step: 39372, Reward: 156.0
# Episode: 514, Step: 39459, Reward: 82.0
# Episode: 515, Step: 39509, Reward: 50.0
# Episode: 516, Step: 39630, Reward: 110.0
# Episode: 517, Step: 39720, Reward: 68.0
# Episode: 518, Step: 39881, Reward: 152.0
# Episode: 519, Step: 40004, Reward: 107.0
# Episode: 520, Step: 40121, Reward: 115.0
# Episode: 521, Step: 40238, Reward: 110.0
# Episode: 522, Step: 40323, Reward: 69.0
# Episode: 523, Step: 40397, Reward: 65.0
# Episode: 524, Step: 40494, Reward: 65.0
# Episode: 525, Step: 40585, Reward: 65.0
# Episode: 526, Step: 40705, Reward: 90.0
# Episode: 527, Step: 40726, Reward: 21.0
# Episode: 528, Step: 40864, Reward: 119.0
# Episode: 529, Step: 40998, Reward: 119.0
# Episode: 530, Step: 41124, Reward: 118.0
# Episode: 531, Step: 41221, Reward: 91.0
# Episode: 532, Step: 41328, Reward: 75.0
# Episode: 533, Step: 41416, Reward: 87.0
# Episode: 534, Step: 41495, Reward: 53.0
# Episode: 535, Step: 41579, Reward: 84.0
# Episode: 536, Step: 41745, Reward: 137.0
# Episode: 537, Step: 41843, Reward: 70.0
# Episode: 538, Step: 41893, Reward: 50.0
# Episode: 539, Step: 42051, Reward: 152.0
# Episode: 540, Step: 42163, Reward: 109.0
# Episode: 541, Step: 42265, Reward: 66.0
# Episode: 542, Step: 42330, Reward: 55.0
# Episode: 543, Step: 42412, Reward: 82.0
# Episode: 544, Step: 42497, Reward: 57.0
# Episode: 545, Step: 42621, Reward: 117.0
# Episode: 546, Step: 42771, Reward: 146.0
# Episode: 547, Step: 42821, Reward: 50.0
# Episode: 548, Step: 42948, Reward: 104.0
# Episode: 549, Step: 43031, Reward: 66.0
# Episode: 550, Step: 43123, Reward: 92.0
# Episode: 551, Step: 43273, Reward: 147.0
# Episode: 552, Step: 43430, Reward: 147.0
# Episode: 553, Step: 43586, Reward: 115.0
# Episode: 554, Step: 43716, Reward: 104.0
# Episode: 555, Step: 43834, Reward: 106.0
# Episode: 556, Step: 43972, Reward: 135.0
# Episode: 557, Step: 44096, Reward: 110.0
# Episode: 558, Step: 44181, Reward: 85.0
# Episode: 559, Step: 44275, Reward: 68.0
# Episode: 560, Step: 44449, Reward: 107.0
# Episode: 561, Step: 44576, Reward: 105.0
# Episode: 562, Step: 44652, Reward: 65.0
# Episode: 563, Step: 44752, Reward: 70.0
# Episode: 564, Step: 44877, Reward: 108.0
# Episode: 565, Step: 44969, Reward: 89.0
# Episode: 566, Step: 45117, Reward: 112.0
# Episode: 567, Step: 45226, Reward: 106.0
# Episode: 568, Step: 45352, Reward: 113.0
# Episode: 569, Step: 45464, Reward: 112.0
# Episode: 570, Step: 45626, Reward: 112.0
# Episode: 571, Step: 45794, Reward: 115.0
# Episode: 572, Step: 45921, Reward: 88.0
# Episode: 573, Step: 46036, Reward: 109.0
# Episode: 574, Step: 46152, Reward: 116.0
# Episode: 575, Step: 46239, Reward: 73.0
# Episode: 576, Step: 46406, Reward: 113.0
# Episode: 577, Step: 46503, Reward: 92.0
# Episode: 578, Step: 46590, Reward: 66.0
# Episode: 579, Step: 46712, Reward: 109.0
# Episode: 580, Step: 46824, Reward: 109.0
# Episode: 581, Step: 46922, Reward: 92.0
# Episode: 582, Step: 47040, Reward: 114.0
# Episode: 583, Step: 47195, Reward: 147.0
# Episode: 584, Step: 47279, Reward: 70.0
# Episode: 585, Step: 47402, Reward: 111.0
# Episode: 586, Step: 47423, Reward: 21.0
# Episode: 587, Step: 47612, Reward: 112.0
# Episode: 588, Step: 47721, Reward: 107.0
# Episode: 589, Step: 47774, Reward: 53.0
# Episode: 590, Step: 47922, Reward: 114.0
# Episode: 591, Step: 48036, Reward: 108.0
# Episode: 592, Step: 48170, Reward: 108.0
# Episode: 593, Step: 48323, Reward: 149.0
# Episode: 594, Step: 48425, Reward: 102.0
# Episode: 595, Step: 48570, Reward: 139.0
# Episode: 596, Step: 48689, Reward: 110.0
# Episode: 597, Step: 48854, Reward: 117.0
# Episode: 598, Step: 48975, Reward: 118.0
# Episode: 599, Step: 49101, Reward: 106.0
# Episode: 600, Step: 49259, Reward: 157.0
# Episode: 601, Step: 49366, Reward: 105.0
# Episode: 602, Step: 49459, Reward: 69.0
# Episode: 603, Step: 49571, Reward: 112.0
# Episode: 604, Step: 49705, Reward: 132.0
# Episode: 605, Step: 49821, Reward: 114.0
# Episode: 606, Step: 49967, Reward: 135.0
# Episode: 607, Step: 50181, Reward: 106.0
# Episode: 608, Step: 50317, Reward: 68.0
# Episode: 609, Step: 50421, Reward: 104.0
# Episode: 610, Step: 50571, Reward: 146.0
# Episode: 611, Step: 50774, Reward: 110.0
# Episode: 612, Step: 50888, Reward: 111.0
# Episode: 613, Step: 51240, Reward: 137.0
# Episode: 614, Step: 51359, Reward: 115.0
# Episode: 615, Step: 51417, Reward: 55.0
# Episode: 616, Step: 51691, Reward: 115.0
# Episode: 617, Step: 51822, Reward: 131.0
# Episode: 618, Step: 51958, Reward: 112.0
# Episode: 619, Step: 52173, Reward: 134.0
# Episode: 620, Step: 52278, Reward: 105.0
# Episode: 621, Step: 52452, Reward: 66.0
# Episode: 622, Step: 52847, Reward: 112.0
# Episode: 623, Step: 52987, Reward: 134.0
# Episode: 624, Step: 53153, Reward: 155.0
# Episode: 625, Step: 53284, Reward: 131.0
# Episode: 626, Step: 53418, Reward: 134.0
# Episode: 627, Step: 53554, Reward: 93.0
# Episode: 628, Step: 54051, Reward: 173.0
# Episode: 629, Step: 54179, Reward: 119.0
# Episode: 630, Step: 54240, Reward: 58.0
# Episode: 631, Step: 54359, Reward: 108.0
# Episode: 632, Step: 54448, Reward: 87.0
# Episode: 633, Step: 54543, Reward: 93.0
# Episode: 634, Step: 54815, Reward: 66.0
# Episode: 635, Step: 55312, Reward: 113.0
# Episode: 636, Step: 55400, Reward: 68.0
# Episode: 637, Step: 55534, Reward: 133.0
# Episode: 638, Step: 55799, Reward: 58.0
# Episode: 639, Step: 55929, Reward: 126.0
# Episode: 640, Step: 56085, Reward: 154.0
# Episode: 641, Step: 56282, Reward: 192.0
# Episode: 642, Step: 56413, Reward: 131.0
# Episode: 643, Step: 56599, Reward: 157.0
# Episode: 644, Step: 56685, Reward: 68.0
# Episode: 645, Step: 56840, Reward: 151.0
# Episode: 646, Step: 56993, Reward: 151.0
# Episode: 647, Step: 57125, Reward: 128.0
# Episode: 648, Step: 57209, Reward: 68.0
# Episode: 649, Step: 57328, Reward: 115.0
# Episode: 650, Step: 57459, Reward: 125.0
# Episode: 651, Step: 57578, Reward: 113.0
# Episode: 652, Step: 57727, Reward: 145.0
# Episode: 653, Step: 58014, Reward: 143.0
# Episode: 654, Step: 58169, Reward: 151.0
# Episode: 655, Step: 58297, Reward: 112.0
# Episode: 656, Step: 58408, Reward: 94.0
# Episode: 657, Step: 58640, Reward: 204.0
# Episode: 658, Step: 58799, Reward: 114.0
# Episode: 659, Step: 58973, Reward: 91.0
# Episode: 660, Step: 59074, Reward: 96.0
# Episode: 661, Step: 59545, Reward: 229.0
# Episode: 662, Step: 59596, Reward: 51.0
# Episode: 663, Step: 59679, Reward: 68.0
# Episode: 664, Step: 60019, Reward: 137.0
# Episode: 665, Step: 60175, Reward: 135.0
# Episode: 666, Step: 60326, Reward: 146.0
# Episode: 667, Step: 60771, Reward: 65.0
# Episode: 668, Step: 60954, Reward: 154.0
# Episode: 669, Step: 61135, Reward: 151.0
# Episode: 670, Step: 61334, Reward: 135.0
# Episode: 671, Step: 61496, Reward: 149.0
# Episode: 672, Step: 61582, Reward: 68.0
# Episode: 673, Step: 61654, Reward: 64.0
# Episode: 674, Step: 61818, Reward: 147.0
# Episode: 675, Step: 62234, Reward: 194.0
# Episode: 676, Step: 62323, Reward: 64.0
# Episode: 677, Step: 62413, Reward: 84.0
# Episode: 678, Step: 62565, Reward: 151.0
# Episode: 679, Step: 62616, Reward: 51.0
# Episode: 680, Step: 62732, Reward: 87.0
# Episode: 681, Step: 62883, Reward: 151.0
# Episode: 682, Step: 62975, Reward: 91.0
# Episode: 683, Step: 63473, Reward: 68.0
# Episode: 684, Step: 63582, Reward: 51.0
# Episode: 685, Step: 63699, Reward: 113.0
# Episode: 686, Step: 63823, Reward: 115.0
# Episode: 687, Step: 64303, Reward: 166.0
# Episode: 688, Step: 64803, Reward: 173.0
# Episode: 689, Step: 65274, Reward: 161.0
# Episode: 690, Step: 65385, Reward: 107.0
# Episode: 691, Step: 65535, Reward: 144.0
# Episode: 692, Step: 66024, Reward: 232.0
# Episode: 693, Step: 66386, Reward: 191.0
# Episode: 694, Step: 66517, Reward: 70.0
# Episode: 695, Step: 66710, Reward: 157.0
# Episode: 696, Step: 66818, Reward: 100.0
# Episode: 697, Step: 66968, Reward: 146.0
# Episode: 698, Step: 67128, Reward: 151.0
# Episode: 699, Step: 67265, Reward: 117.0
# Episode: 700, Step: 67481, Reward: 132.0
# Episode: 701, Step: 67765, Reward: 125.0
# Episode: 702, Step: 67848, Reward: 67.0
# Episode: 703, Step: 67966, Reward: 114.0
# Episode: 704, Step: 68116, Reward: 109.0
# Episode: 705, Step: 68224, Reward: 65.0
# Episode: 706, Step: 68350, Reward: 122.0
# Episode: 707, Step: 68429, Reward: 51.0
# Episode: 708, Step: 68546, Reward: 114.0
# Episode: 709, Step: 68671, Reward: 122.0
# Episode: 710, Step: 68832, Reward: 156.0
# Episode: 711, Step: 68990, Reward: 154.0
# Episode: 712, Step: 69041, Reward: 51.0
# Episode: 713, Step: 69092, Reward: 51.0
# Episode: 714, Step: 69576, Reward: 185.0
# Episode: 715, Step: 69681, Reward: 105.0
# Episode: 716, Step: 69766, Reward: 68.0
# Episode: 717, Step: 69856, Reward: 72.0
# Episode: 718, Step: 70354, Reward: 191.0
# Episode: 719, Step: 70435, Reward: 66.0
# Episode: 720, Step: 70823, Reward: 200.0
# Episode: 721, Step: 71307, Reward: 182.0
# Episode: 722, Step: 71461, Reward: 149.0
# Episode: 723, Step: 71961, Reward: 171.0
# Episode: 724, Step: 72065, Reward: 104.0
# Episode: 725, Step: 72214, Reward: 146.0
# Episode: 726, Step: 72330, Reward: 114.0
# Episode: 727, Step: 72819, Reward: 175.0
# Episode: 728, Step: 72971, Reward: 150.0
# Episode: 729, Step: 73451, Reward: 175.0
# Episode: 730, Step: 73606, Reward: 148.0
# Episode: 731, Step: 73735, Reward: 114.0
# Episode: 732, Step: 73878, Reward: 135.0
# Episode: 733, Step: 74375, Reward: 239.0
# Episode: 734, Step: 74471, Reward: 53.0
# Episode: 735, Step: 74622, Reward: 147.0
# Episode: 736, Step: 74905, Reward: 65.0
# Episode: 737, Step: 75057, Reward: 148.0
# Episode: 738, Step: 75210, Reward: 112.0
# Episode: 739, Step: 75363, Reward: 65.0
# Episode: 740, Step: 75513, Reward: 147.0
# Episode: 741, Step: 75644, Reward: 53.0
# Episode: 742, Step: 75805, Reward: 66.0
# Episode: 743, Step: 75997, Reward: 187.0
# Episode: 744, Step: 76086, Reward: 50.0
# Episode: 745, Step: 76253, Reward: 110.0
# Episode: 746, Step: 76374, Reward: 113.0
# Episode: 747, Step: 76632, Reward: 150.0
# Episode: 748, Step: 76772, Reward: 130.0
# Episode: 749, Step: 77012, Reward: 198.0
# Episode: 750, Step: 77492, Reward: 172.0
# Episode: 751, Step: 77992, Reward: 164.0
# Episode: 752, Step: 78111, Reward: 106.0
# Episode: 753, Step: 78185, Reward: 63.0
# Episode: 754, Step: 78326, Reward: 112.0
# Episode: 755, Step: 78473, Reward: 137.0
# Episode: 756, Step: 78693, Reward: 194.0
# Episode: 757, Step: 78747, Reward: 54.0
# Episode: 758, Step: 78846, Reward: 59.0
# Episode: 759, Step: 79023, Reward: 155.0
# Episode: 760, Step: 79283, Reward: 124.0
# Episode: 761, Step: 79527, Reward: 192.0
# Episode: 762, Step: 80012, Reward: 218.0
# Episode: 763, Step: 80496, Reward: 171.0
# Episode: 764, Step: 80643, Reward: 147.0
# Episode: 765, Step: 80792, Reward: 126.0
# Episode: 766, Step: 80950, Reward: 145.0
# Episode: 767, Step: 81225, Reward: 195.0
# Episode: 768, Step: 81365, Reward: 104.0
# Episode: 769, Step: 81463, Reward: 69.0
# Episode: 770, Step: 81869, Reward: 214.0
# Episode: 771, Step: 82012, Reward: 133.0
# Episode: 772, Step: 82167, Reward: 112.0
# Episode: 773, Step: 82263, Reward: 58.0
# Episode: 774, Step: 82317, Reward: 54.0
# Episode: 775, Step: 82430, Reward: 113.0
# Episode: 776, Step: 82543, Reward: 113.0
# Episode: 777, Step: 82663, Reward: 116.0
# Episode: 778, Step: 82769, Reward: 106.0
# Episode: 779, Step: 82920, Reward: 147.0
# Episode: 780, Step: 83391, Reward: 172.0
# Episode: 781, Step: 83571, Reward: 146.0
# Episode: 782, Step: 83720, Reward: 149.0
# Episode: 783, Step: 84034, Reward: 106.0
# Episode: 784, Step: 84531, Reward: 257.0
# Episode: 785, Step: 84674, Reward: 143.0
# Episode: 786, Step: 85174, Reward: 198.0
# Episode: 787, Step: 85634, Reward: 198.0
# Episode: 788, Step: 86112, Reward: 251.0
# Episode: 789, Step: 86259, Reward: 146.0
# Episode: 790, Step: 86365, Reward: 106.0
# Episode: 791, Step: 86849, Reward: 182.0
# Episode: 792, Step: 87003, Reward: 147.0
# Episode: 793, Step: 87184, Reward: 127.0
# Episode: 794, Step: 87642, Reward: 215.0
# Episode: 795, Step: 88140, Reward: 176.0
# Episode: 796, Step: 88229, Reward: 67.0
# Episode: 797, Step: 88614, Reward: 210.0
# Episode: 798, Step: 88670, Reward: 55.0
# Episode: 799, Step: 88726, Reward: 55.0
# Episode: 800, Step: 88894, Reward: 152.0
# Episode: 801, Step: 89150, Reward: 197.0
# Episode: 802, Step: 89305, Reward: 153.0
# Episode: 803, Step: 89455, Reward: 150.0
# Episode: 804, Step: 89578, Reward: 123.0
# Episode: 805, Step: 89710, Reward: 132.0
# Episode: 806, Step: 89999, Reward: 143.0
# Episode: 807, Step: 90305, Reward: 194.0
# Episode: 808, Step: 90410, Reward: 105.0
# Episode: 809, Step: 90562, Reward: 151.0
# Episode: 810, Step: 90714, Reward: 152.0
# Episode: 811, Step: 91155, Reward: 192.0
# Episode: 812, Step: 91294, Reward: 132.0
# Episode: 813, Step: 91418, Reward: 124.0
# Episode: 814, Step: 91567, Reward: 149.0
# Episode: 815, Step: 91721, Reward: 135.0
# Episode: 816, Step: 91873, Reward: 147.0
# Episode: 817, Step: 91936, Reward: 56.0
# Episode: 818, Step: 92102, Reward: 150.0
# Episode: 819, Step: 92225, Reward: 123.0
# Episode: 820, Step: 92705, Reward: 176.0
# Episode: 821, Step: 92888, Reward: 126.0
# Episode: 822, Step: 93275, Reward: 192.0
# Episode: 823, Step: 93422, Reward: 146.0
# Episode: 824, Step: 93684, Reward: 195.0
# Episode: 825, Step: 93830, Reward: 146.0
# Episode: 826, Step: 94073, Reward: 199.0
# Episode: 827, Step: 94230, Reward: 149.0
# Episode: 828, Step: 94380, Reward: 149.0
# Episode: 829, Step: 94461, Reward: 55.0
# Episode: 830, Step: 94616, Reward: 152.0
# Episode: 831, Step: 94766, Reward: 149.0
# Episode: 832, Step: 95255, Reward: 181.0
# Episode: 833, Step: 95500, Reward: 192.0
# Episode: 834, Step: 95644, Reward: 144.0
# Episode: 835, Step: 96023, Reward: 212.0
# Episode: 836, Step: 96170, Reward: 147.0
# Episode: 837, Step: 96594, Reward: 212.0
# Episode: 838, Step: 96967, Reward: 255.0
# Episode: 839, Step: 97191, Reward: 194.0
# Episode: 840, Step: 97382, Reward: 189.0
# Episode: 841, Step: 97581, Reward: 157.0
# Episode: 842, Step: 97704, Reward: 123.0
# Episode: 843, Step: 98085, Reward: 218.0
# Episode: 844, Step: 98282, Reward: 192.0
# Episode: 845, Step: 98779, Reward: 190.0
# Episode: 846, Step: 98890, Reward: 111.0
# Episode: 847, Step: 99013, Reward: 123.0
# Episode: 848, Step: 99147, Reward: 129.0
# Episode: 849, Step: 99637, Reward: 261.0
# Episode: 850, Step: 99749, Reward: 99.0
# Episode: 851, Step: 100080, Reward: 195.0
# Episode: 852, Step: 100354, Reward: 196.0
# Episode: 853, Step: 100497, Reward: 137.0
# Episode: 854, Step: 100611, Reward: 114.0
# Episode: 855, Step: 100767, Reward: 147.0
# Episode: 856, Step: 101267, Reward: 188.0
# Episode: 857, Step: 101738, Reward: 165.0
# Episode: 858, Step: 101889, Reward: 151.0
# Episode: 859, Step: 102089, Reward: 186.0
# Episode: 860, Step: 102238, Reward: 149.0
# Episode: 861, Step: 102538, Reward: 192.0
# Episode: 862, Step: 102652, Reward: 114.0
# Episode: 863, Step: 103152, Reward: 184.0
# Episode: 864, Step: 103281, Reward: 128.0
# Episode: 865, Step: 103394, Reward: 97.0
# Episode: 866, Step: 103698, Reward: 133.0
# Episode: 867, Step: 103754, Reward: 55.0
# Episode: 868, Step: 104238, Reward: 157.0
# Episode: 869, Step: 104718, Reward: 170.0
# Episode: 870, Step: 104926, Reward: 129.0
# Episode: 871, Step: 105221, Reward: 197.0
# Episode: 872, Step: 105381, Reward: 154.0
# Episode: 873, Step: 105878, Reward: 167.0
# Episode: 874, Step: 106366, Reward: 263.0
# Episode: 875, Step: 106623, Reward: 193.0
# Episode: 876, Step: 106764, Reward: 137.0
# Episode: 877, Step: 106927, Reward: 150.0
# Episode: 878, Step: 107065, Reward: 133.0
# Episode: 879, Step: 107186, Reward: 115.0
# Episode: 880, Step: 107330, Reward: 138.0
# Episode: 881, Step: 107488, Reward: 142.0
# Episode: 882, Step: 107972, Reward: 185.0
# Episode: 883, Step: 108099, Reward: 125.0
# Episode: 884, Step: 108376, Reward: 197.0
# Episode: 885, Step: 108521, Reward: 134.0
# Episode: 886, Step: 108664, Reward: 143.0
# Episode: 887, Step: 109161, Reward: 181.0
# Episode: 888, Step: 109310, Reward: 149.0
# Episode: 889, Step: 109396, Reward: 68.0
# Episode: 890, Step: 109609, Reward: 195.0
# Episode: 891, Step: 109949, Reward: 196.0
# Episode: 892, Step: 110420, Reward: 237.0
# Episode: 893, Step: 110571, Reward: 148.0
# Episode: 894, Step: 111068, Reward: 165.0
# Episode: 895, Step: 111302, Reward: 189.0
# Episode: 896, Step: 111786, Reward: 189.0
# Episode: 897, Step: 112128, Reward: 196.0
# Episode: 898, Step: 112215, Reward: 86.0
# Episode: 899, Step: 112322, Reward: 101.0
# Episode: 900, Step: 112405, Reward: 83.0
# Episode: 901, Step: 112528, Reward: 111.0
# Episode: 902, Step: 112677, Reward: 149.0
# Episode: 903, Step: 113129, Reward: 193.0
# Episode: 904, Step: 113368, Reward: 198.0
# Episode: 905, Step: 113506, Reward: 134.0
# Episode: 906, Step: 113654, Reward: 146.0
# Episode: 907, Step: 113803, Reward: 147.0
# Episode: 908, Step: 114229, Reward: 199.0
# Episode: 909, Step: 114383, Reward: 148.0
# Episode: 910, Step: 114548, Reward: 153.0
# Episode: 911, Step: 114685, Reward: 137.0
# Episode: 912, Step: 114838, Reward: 151.0
# Episode: 913, Step: 115052, Reward: 195.0
# Episode: 914, Step: 115550, Reward: 221.0
# Episode: 915, Step: 115639, Reward: 89.0
# Episode: 916, Step: 115765, Reward: 126.0
# Episode: 917, Step: 115878, Reward: 113.0
# Episode: 918, Step: 116014, Reward: 136.0
# Episode: 919, Step: 116161, Reward: 147.0
# Episode: 920, Step: 116312, Reward: 151.0
# Episode: 921, Step: 116418, Reward: 106.0
# Episode: 922, Step: 116502, Reward: 68.0
# Episode: 923, Step: 116585, Reward: 66.0
# Episode: 924, Step: 117007, Reward: 192.0
# Episode: 925, Step: 117138, Reward: 131.0
# Episode: 926, Step: 117252, Reward: 113.0
# Episode: 927, Step: 117533, Reward: 190.0
# Episode: 928, Step: 117794, Reward: 222.0
# Episode: 929, Step: 118135, Reward: 152.0
# Episode: 930, Step: 118624, Reward: 198.0
# Episode: 931, Step: 118677, Reward: 53.0
# Episode: 932, Step: 118810, Reward: 133.0
# Episode: 933, Step: 118897, Reward: 86.0
# Episode: 934, Step: 119041, Reward: 138.0
# Episode: 935, Step: 119105, Reward: 58.0
# Episode: 936, Step: 119265, Reward: 154.0
# Episode: 937, Step: 119402, Reward: 136.0
# Episode: 938, Step: 119692, Reward: 259.0
# Episode: 939, Step: 120172, Reward: 179.0
# Episode: 940, Step: 120336, Reward: 126.0
# Episode: 941, Step: 120488, Reward: 87.0
# Episode: 942, Step: 120986, Reward: 186.0
# Episode: 943, Step: 121070, Reward: 68.0
# Episode: 944, Step: 121559, Reward: 209.0
# Episode: 945, Step: 122043, Reward: 169.0
# Episode: 946, Step: 122130, Reward: 86.0
# Episode: 947, Step: 122485, Reward: 260.0
# Episode: 948, Step: 122545, Reward: 55.0
# Episode: 949, Step: 122703, Reward: 151.0
# Episode: 950, Step: 123200, Reward: 218.0
# Episode: 951, Step: 123352, Reward: 152.0
# Episode: 952, Step: 123836, Reward: 168.0
# Episode: 953, Step: 123990, Reward: 150.0
# Episode: 954, Step: 124490, Reward: 167.0
# Episode: 955, Step: 124623, Reward: 133.0
# Episode: 956, Step: 124770, Reward: 147.0
# Episode: 957, Step: 124917, Reward: 147.0
# Episode: 958, Step: 125406, Reward: 158.0
# Episode: 959, Step: 125491, Reward: 85.0
# Episode: 960, Step: 125862, Reward: 188.0
# Episode: 961, Step: 125884, Reward: 22.0
# Episode: 962, Step: 126087, Reward: 188.0
# Episode: 963, Step: 126410, Reward: 194.0
# Episode: 964, Step: 126665, Reward: 154.0
# Episode: 965, Step: 126787, Reward: 122.0
# Episode: 966, Step: 127271, Reward: 164.0
# Episode: 967, Step: 127395, Reward: 124.0
# Episode: 968, Step: 127702, Reward: 215.0
# Episode: 969, Step: 127815, Reward: 113.0
# Episode: 970, Step: 127922, Reward: 107.0
# Episode: 971, Step: 128035, Reward: 113.0
# Episode: 972, Step: 128148, Reward: 113.0
# Episode: 973, Step: 128245, Reward: 88.0
# Episode: 974, Step: 128725, Reward: 229.0
# Episode: 975, Step: 128879, Reward: 147.0
# Episode: 976, Step: 129028, Reward: 149.0
# Episode: 977, Step: 129499, Reward: 260.0
# Episode: 978, Step: 129955, Reward: 256.0
# Episode: 979, Step: 130197, Reward: 199.0
# Episode: 980, Step: 130275, Reward: 66.0
# Episode: 981, Step: 130441, Reward: 157.0
# Episode: 982, Step: 130546, Reward: 105.0
# Episode: 983, Step: 130683, Reward: 136.0
# Episode: 984, Step: 130825, Reward: 134.0
# Episode: 985, Step: 131322, Reward: 230.0
# Episode: 986, Step: 131420, Reward: 86.0
# Episode: 987, Step: 131577, Reward: 150.0
# Episode: 988, Step: 131932, Reward: 190.0
# Episode: 989, Step: 132175, Reward: 214.0
# Episode: 990, Step: 132646, Reward: 190.0
# Episode: 991, Step: 132858, Reward: 190.0
# Episode: 992, Step: 132915, Reward: 56.0
# Episode: 993, Step: 133070, Reward: 154.0
# Episode: 994, Step: 133554, Reward: 227.0
# Episode: 995, Step: 134034, Reward: 234.0
# Episode: 996, Step: 134184, Reward: 149.0
# Episode: 997, Step: 134655, Reward: 170.0
# Episode: 998, Step: 134856, Reward: 195.0
# Episode: 999, Step: 135353, Reward: 192.0
# Episode: 1000, Step: 135842, Reward: 209.0

# %%
def valid():
    
    agent = CNNQNetwork(env.observation_space.shape, n_action=2).to(device)
    state_dict = torch.load("models/dqn_agent_gen_150.pt")
    agent.load_state_dict(state_dict)
    
    for episode in range(5):
        obs_ = env.reset()

        step_ = 0
        done_ = False
        while not done_:           
            action_ = agent.act(obs_.float().to(device), epsilon=0.0)
            next_obs_, reward_, done_, _ = env.step(make_action(action_))
            obs_ = next_obs_
            step_ += 1
            
            #controller = "→" if action_ == 0 else "→A"
            #text = f"Step: {step_} Action: {controller}"
            #print(f"\r{text}", end="")
    
        #print(f"\r{'Finished'}", end="")
    
valid()
